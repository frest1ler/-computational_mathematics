# %% [markdown]
# # Решение СЛАУ различными методами
#
# ## Вариант у
#
# ### Параметры системы:
# - Размерность: n = 12
# - Диагональные элементы: $a_{ii} = 1$
# - Внедиагональные элементы: $a_{ij} = \frac{1}{i^2 + j}$ при $i \neq j$
# - Вектор правой части: $f_i = \frac{1}{i}$
#
# ### Реализованные методы:
# 1. **Прямые методы:** Гаусса, LU-разложение
# 2. **Итерационные методы:** Якоби, Зейделя, SOR, градиентный спуск, минимальные невязки, сопряженные градиенты

# %% [markdown]
# ## 1. Анализ системы

# %%
# Формирование и анализ системы
# Out:
# Размерность системы: 12×12
# Число обусловленности: 2.23e+00
# Определитель матрицы: 8.59e-01
# Норма матрицы: 3.54e+00

# %% [markdown]
# ## 2. Прямые методы
#
# ### 2.1. Метод Гаусса с выбором главного элемента

# %%
# Метод Гаусса
# Out:
# Метод Гаусса:
# Время выполнения: 0.000513 сек
# Невязка: 2.29e-16
# Первые компоненты решения: [0.75537042 0.23879963 0.17890325 0.15086988 0.13170938]

# %% [markdown]
# ### 2.2. Метод LU-разложения

# %%
# LU-разложение
# Out:
# LU-разложение:
# Время выполнения: 0.000587 сек
# Невязка: 2.29e-16

# %% [markdown]
# ## 3. Итерационные методы
#
# ### 3.1. Метод Якоби

# %%
# Метод Якоби
# Out:
# Метод Якоби:
# Итераций: 36
# Время выполнения: 0.002814 сек
# Невязка: 7.52e-11

# %% [markdown]
# ### 3.2. Сравнение методов Якоби и Зейделя

# %%
# Сравнение Якоби и Зейделя
# Out:
# Сравнение:
# Якоби: 36 итераций, невязка 7.52e-11
# Зейделя: 10 итераций, невязка 9.43e-11

# %% [markdown]
# ## 4. Комплексное сравнение всех методов

# %%
# Полное сравнение
# Out:
# СРАВНИТЕЛЬНАЯ ТАБЛИЦА:
#       Метод          Тип Время (мс) Итерации  Невязка
#       Гаусс       Прямой       0.51        - 2.29e-16
#          LU       Прямой       0.59        - 2.29e-16
#       Якоби Итерационный       2.81       36 7.52e-11
#     Зейделя Итерационный       0.80       10 9.43e-11
#         SOR Итерационный       1.86       23 6.96e-11
#  Град.спуск Итерационный       0.35       20 4.91e-11
# Мин.невязки Итерационный       0.32       17 2.64e-11
#  Сопр.град. Итерационный       0.24       12 1.01e-07

# %% [markdown]
# ## 5. Влияние начального приближения

# %%
# Влияние начального приближения

# %% [markdown]
# ## 6. Выводы
#
# ### Результаты исследования:
#
# 1. **Прямые методы** (Гаусс, LU):
#    - ✅ Дают точное решение с машинной точностью
#    - ✅ Не зависят от начального приближения
#    - ❌ Вычислительная сложность O(n³)
#
# 2. **Классические итерационные** (Якоби, Зейделя, SOR):
#    - ✅ Простая реализация
#    - ✅ Малые требования к памяти
#    - 📊 Зейдель сходится быстрее Якоби
#    - 📊 SOR с оптимальным ω ускоряет сходимость
#
# 3. **Градиентные методы**:
#    - ✅ Не требуют специальной структуры матрицы
#    - 📊 Метод сопряженных градиентов - самый эффективный
#    - 📊 Сходится за малое число итераций
#
# ### Рекомендации:
# - Для данной системы (n=12) оптимален **метод сопряженных градиентов**
# - Для больших разреженных систем - итерационные методы
# - Для малых плотных систем - прямые методы
